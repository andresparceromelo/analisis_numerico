# %% [markdown]
# TALLER DE CEROS (BISECCIÓN, POSICIÓN FALSA, SECANTE, NEWTON)
#
# Integrantes:
#
# Andres Bedoya Cano
# Juliana Franco
#
# NOTA:
#
# Profe, qué más?
#
# Este es el archivo principal, el cual tiene la linea general de todas las soluciones del taller.
# Aquí están las redirecciones necesarias para revisar nuestro desarrollo en cada punto.

# %% [markdown]
# PUNTO 1:
# [Ir al notebook del Punto 1](punto1_taller.ipynb)

# %% [markdown]
# PUNTO 2:
# [Ir al notebook del Punto 2](punto2_taller.ipynb)

# %% [markdown]
# PUNTO 3:
# [Ir al notebook del Punto 3](punto3_taller.ipynb)

# %% [markdown]
# PUNTO 4:
# [Ir al notebook del Punto 4](punto4_taller.ipynb)
